# %% [markdown]
# # Tutorial 3 - Python For Data Analysis 🐍
# ---
# ## 📈 Matplotlib & Seaborn 📉

# %% [markdown]
# ### *Table of Contents*
#
#   - [Exercise 1](#exercise-1) : Matplotlib Basics
#   - [Exercise 2](#exercise-2) : Matplotlib's Object Oriented API
#   - [Exercise 3](#exercise-3) : Pandas Built-in
#   - [Exercise 4](#exercise-4) : Traffic accidents - Seaborn

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

#Affichage avec la bibliothèque graphique intégrée à Notebook
# %matplotlib inline

# %% [markdown]
# <a name="exercise-1">
#
# ### Exercise 1 : Matplotlib Basics
# ---

# %% [markdown]
# #### 1) Create `x` and `y`NumPy arrays, such as `x` have values from 1 to 5, with a 0.5 step.
# ‘y’ will be the square of ‘x’. Then, create a plot using ‘x’ and ‘y’.

# %%
x=np.arange(1,5,0.5)
y=x**2

# %% [markdown]
# #### 2) On the same plot, add a title for the graph, x axis and y axis

# %%
plt.plot(x,y)
plt.xlabel("les X")
plt.ylabel("les Y")
plt.show()

# %% [markdown]
# #### 3) Change the color of the line. Where can you find all named colors known by matplotlib?

# %%
plt.plot(x,y,'r')
plt.xlabel("les X")
plt.ylabel("les Y")

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 4) Create a multiplot having 2 rows and 2 columns. Such as :

# %% [markdown]
# a) First plot containing $y=x^2$

# %% [markdown]
# b) Second plot containing $y=x^3$

# %% [markdown]
# c) (second row) Third plot containing $y=log(x)$

# %% [markdown]
# d) Fourth plot containing $y=e^x$

# %%
plt.subplot(2,2,1)
plt.plot(x,x**2)

plt.subplot(2,2,2)
plt.plot(x,x**3)

plt.subplot(2,2,3)
plt.plot(x,np.log(x))

plt.subplot(2,2,4)
plt.plot(x,np.exp(x))

plt.show()

# %% [markdown]
# <a name="exercise-2">
#
# ### Exercise 2 : Matplotlib's Object Oriented API
# ---

# %% [markdown]
# Matplotlib have an object-oriented API used to create more complex figures. Code is a
# little more complicated, but the advantage is that we now have full control of where the plot axes. Here’s a good read when exploring matplotlib
#
# https://github.com/rougier/matplotlib-tutorial

# %% [markdown]
# #### 1) Create the same chart as 1.1 using the new method: instantiate figure objects and then call methods or attributes from that object.

# %%
x=np.arange(1,5,0.5)
y=x**2

fig,ax=plt.subplots()

ax.plot(x,y,c='blue')
ax.set_xlabel("X")
ax.set_ylabel('Y')
ax.set_title("first plot")
# Out:
# Text(0.5, 1.0, 'first plot')

# %% [markdown]
# #### 2) Create the figure below (the blue curve represents $y=x^2$ while the red curve represents $x=y^2$)

# %%
x=np.arange(1,5,0.5)
y=x**2

fig=plt.figure(figsize=(10,6), dpi=80)

ax1=fig.add_axes([0.1,0.1,0.8,0.8])   #main axes
ax2=fig.add_axes([0.48,0.25,0.4,0.3])                  #inserted axe 


#main fig Ax1
ax1.plot(y,x,c='blue',marker='o')
ax1.set_xlabel('X label')
ax1.set_ylabel('Y label')
ax1.set_title('fig main title')

#second figure Ax2
ax2.plot(y,x,c='blue',marker='o')
ax2.set_xlabel('X second label')
ax2.set_ylabel('Y second label')
ax2.set_title('fig sub title')



#plt.figure(figsize=(10,6), dpi=80)
#plt.plot(x, y, color="blue", linewidth=2.5, linestyle="-")
#y=np.sqrt(x)
#plt.plot(x, y, color="red", linewidth=2.5, linestyle="-")
# Out:
# Text(0.5, 1.0, 'fig sub title')

# %% [markdown]
# #### 3) Explore colors and markers style. Create a new chart, such as x goes from 0 to 10, and $y=x+index$.
#
# *index* is the number of curves you're going to draw. For example, the first curve will match $y=x+0$, the second $y=x+1$, etc...
#
# Create multiple combinations of differents colors, markers & marker size in this graphic. Here's an example using three curves:

# %%
x=np.arange(0,10,0.5)

fig,ax = plt.subplots(figsize=(20,10))



ax.plot(x,x,'red',label='line 1', linewidth=2)
ax.plot(x,x+1,'k--',marker='X',label='Python')
ax.plot(x,x+2,'b',linestyle=':',marker='o',label='label3')

ax.set_title('example')
# Out:
# Text(0.5, 1.0, 'example')

# %% [markdown]
# #### 4) Create the same subplots you've created in 1.4 using matplotlib API (use `plt.subplots()`

# %% [markdown]
# a. Add a title for each plot ‘title 1’, ‘title 2’, etc.
#
# b. Add an x axis and y axis label for each plot (for example, x-axis: X, y-axis: f(x)= x^2
#
# c. Use figsize to make it clearer
#
# d. Show legend on chart
#
# e. Differentiate between each graph using a different color and markers

# %%
x=np.arange(1,10,0.5)

fig, axes = plt.subplots(nrows=2,ncols=2,figsize=(20,10))

axes[0,0].plot(x,x**2, label="square")
axes[0,0].set_title("figure 1")

axes[1,0].plot(x,x**3, label="cube")
axes[1,0].set_title("figure 2")

axes[0,1].plot(x,np.log(x), label="log")
axes[0,1].set_title("figure 3")

axes[1,1].plot(x,np.exp(x), label="exp")
axes[1,1].set_title("figure 4")

for ax in axes.flat:
    ax.legend(loc='upper left')
    
fig.tight_layout()

# %% [markdown]
# <a name="exercise-3">
#
# ### Exercise 3 : Pandas Built-in
# ---

# %% [markdown]
# On every plot graph, you can use plt.style.use(theme) to change the style of your plot. https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
#
# You can find all available graphs on pandas here:
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html

# %% [markdown]
# #### 1) Create a pandas dataframe, having 5000 rows and 4 random columns. First column should be called ‘col_1’, second one ‘col_2’, etc.

# %%
df = pd.DataFrame(np.random.rand(5000, 4), columns=['col_1','col_2',"col_3","col_4"])

# %% [markdown]
# #### 2) Using pandas built-in visualization, create a scatter plot that will show col_1 vs col_2. Try it again with col_3 vs col_4.
# Hint: use df.plot.scatter

# %%
df.plot.scatter('col_1',"col_2")
df.plot.scatter('col_3',"col_4",color='red')
# Out:
# <AxesSubplot:xlabel='col_3', ylabel='col_4'>

# %% [markdown]
# #### 3) On the first plot, add col_3 as a color column, and col_4 as a size column. This means that the more col_3 is increased, the more the color will be different. And the more col_4 increases, the bigger its size will be.
# Hint: if the size is very small, consider multiply it by * 10, even by 100 if needed.

# %%
#df.plot.scatter(x='col_1',y="col_2",color=df['col_3'])
#df.plot.scatter(x='col_1',y="col_2",color=df['col_3'],s=df['col_4']*100)
df.plot.scatter(x='col_1',y="col_2",c=df['col_3'],s=df['col_4']*100,cmap='coolwarm',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='col_1', ylabel='col_2'>

# %% [markdown]
# #### 4) Display the frequency bar (histogram) of the first column. As you can see, we can’t identify anything using the default plot configuration. Can you refine the result so that we can see more detail in the plot?

# %%
#df['col_4'].plot.hist()
df['col_1'].plot.hist(histtype='step' )
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['col_1'].plot.hist(alpha=0.5,bins=100,figsize=(20,10),grid=True,width = 1/200)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### 5) Create a boxplot representing the distribution of the 4 columns on the same graph. Can you display the first two only?

# %%
plt.boxplot(df)
#ou
df.plot(kind='box')
#affichons seulement 2
df[['col_1','col_2']].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 6) Plot the first 200 rows of the dataframe.

# %%
#plt.plot(df.head(200))
ax=df.iloc[0:200].plot.area(figsize=(20,10),alpha=0.4)
ax.set_title("first 200 rows")
plt.show()

# %% [markdown]
# #### 7) Create two plots side by side, the first one is using scatter plot (as seen previously) and the second one use hexbin plot.

# %%
plt.figure(figsize=(20,6))

plt.subplot(1,2,1)
plt.hexbin(df['col_1'],df['col_2'] , gridsize = 25, cmap ='Greens')

plt.subplot(1,2,2)
plt.scatter(x=df['col_1'],y=df["col_2"],c=df['col_3'],s=df['col_4']*100)


plt.show()

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(20,6),squeeze=False)

df.plot.hexbin(x='col_1',y='col_2',gridsize=25,cmap='Oranges',ax=axes[0,0])
df.plot.scatter(x='col_1',y='col_2',color='orange',ax=axes[0,1])
# Out:
# <AxesSubplot:xlabel='col_1', ylabel='col_2'>

# %% [markdown]
# <a name="exercise-4">
#
# ### Exercise 4 : Traffic Accidents - Seaborn
# ---

# %% [markdown]
# In EDA (Exploratory Data Analysis), we rarely use matplotlib directly. We use it for highly customized visualizations. For quick plots, we can use pandas built-in plots or use external libraries, like Seaborn.
#
# We can also use more developed libraries like plotly or bokeh, allowing to create interactive visualizations and entire dashboards.
#
# Get the dataframe we used in the previous TP. Don’t forget to add a title, x labels, y labels to every plot you make! Visualizations are used to communicate with people who are nontech- nical and/or who have never seen your data.
#
#
# https://seaborn.pydata.org/generated/seaborn.heatmap.html

# %%
from mapping import *
# don't forget to import mapping.py and vehicules_2016.csv

# %%
vehicules_2016 = pd.read_csv("vehicules_2016.csv", encoding="latin1")
vehicules_2016.columns = ["Num_Acc", "sens_de_Circulation", "catV",
                          "nb_occupants", "obstacle_fixe", "obstacle_mobile", 
                          "choc", "manoeuvre" , "num_vehicule" ]
vehicules_2016["label_vehicule"]=vehicules_2016.catV.map(info_vehicules)
vehicules_2016["label_obstacle_mobile"] = vehicules_2016.obstacle_mobile.map(obstacle_labels)
vehicules_2016["label_obstacle_fixe"] = vehicules_2016.obstacle_fixe.map(obstacle_fixe_labels)
vehicules_2016.head()

vehicules_2016.head(10)
# Out:
#         Num_Acc  sens_de_Circulation  catV  nb_occupants  obstacle_fixe  \
# 0  201600000001                  0.0     7             0            0.0
# 1  201600000001                  0.0     2             0            0.0
# 2  201600000002                  0.0     7             0            6.0
# 3  201600000003                  0.0     7             0            0.0
# 4  201600000004                  0.0    32             0            0.0
# 5  201600000004                  0.0     7             0            0.0
# 6  201600000005                  0.0    30             0            0.0
# 7  201600000005                  0.0     7             0            0.0
# 8  201600000006                  0.0     7             0            0.0
# 9  201600000007                  1.0    30             0            0.0
#
#    obstacle_mobile  choc  manoeuvre num_vehicule           label_vehicule  \
# 0              0.0   1.0        1.0          B02                  VL seul
# 1              0.0   7.0       15.0          A01       Cyclomoteur <50cm3
# 2              0.0   1.0        1.0          A01                  VL seul
# 3              1.0   6.0        1.0          A01                  VL seul
# 4              0.0   1.0        1.0          B02  Scooter >50cm et<=125cm
# 5              0.0   8.0       15.0          A01                  VL seul
# 6              2.0   1.0       15.0          B02         Scooter < 50 cm3
# 7              2.0   3.0        1.0          A01                  VL seul
# 8              1.0   1.0        1.0          A01                  VL seul
# 9              0.0   3.0       15.0          A01         Scooter < 50 cm3
#
#   label_obstacle_mobile           label_obstacle_fixe
# 0             inconnu_0                           NaN
# 1             inconnu_0                           NaN
# 2             inconnu_0  Bâtiment, mur, pile de pont
# 3               Piéton                           NaN
# 4             inconnu_0                           NaN
# 5             inconnu_0                           NaN
# 6             Véhicule                           NaN
# 7             Véhicule                           NaN
# 8               Piéton                           NaN
# 9             inconnu_0                           NaN

# %% [markdown]
# #### 1) Use the dataframe you created on 2.25, representing the relationship between ‘moving obstacles’ and ‘transport vehicles’. Create a dataframe using this data, marking the correlation between each variable in the heatmap. Add a title and change the style of this plot. Here’s an example of the expected output:

# %%
vehicules_2016.loc[(vehicules_2016["catV"]>=37) & (vehicules_2016["catV"]<=40)]
vehicules_2016.head(5)
#df2=pd.pivot_table(vehicules_2016,index='catV',columns='obstacle_mobile',values='nb_occupants',aggfunc='sum')
# Out:
#         Num_Acc  sens_de_Circulation  catV  nb_occupants  obstacle_fixe  \
# 0  201600000001                  0.0     7             0            0.0
# 1  201600000001                  0.0     2             0            0.0
# 2  201600000002                  0.0     7             0            6.0
# 3  201600000003                  0.0     7             0            0.0
# 4  201600000004                  0.0    32             0            0.0
#
#    obstacle_mobile  choc  manoeuvre num_vehicule           label_vehicule  \
# 0              0.0   1.0        1.0          B02                  VL seul
# 1              0.0   7.0       15.0          A01       Cyclomoteur <50cm3
# 2              0.0   1.0        1.0          A01                  VL seul
# 3              1.0   6.0        1.0          A01                  VL seul
# 4              0.0   1.0        1.0          B02  Scooter >50cm et<=125cm
#
#   label_obstacle_mobile           label_obstacle_fixe
# 0             inconnu_0                           NaN
# 1             inconnu_0                           NaN
# 2             inconnu_0  Bâtiment, mur, pile de pont
# 3               Piéton                           NaN
# 4             inconnu_0                           NaN

# %%
df2=pd.pivot_table(vehicules_2016.loc[(vehicules_2016["catV"]>=37) & (vehicules_2016["catV"]<=40)],index='catV',columns='obstacle_mobile',values='nb_occupants',aggfunc='sum')
sns.heatmap(df2)
# Out:
# <AxesSubplot:xlabel='obstacle_mobile', ylabel='catV'>

# %% [markdown]
# #### 2) Create a pie chart representing the frequency of ‘accident numbers’ by ‘type of mov- ing obstacle’

# %% [markdown]
# #### 3) Modify the previous plot to have the frequency of the single accident numbers

# %% [markdown]
# #### 4) Calculate the ‘'number of accidents’ per ‘fixed obstacle’. Visualize the result in a hori- zontal bar chart.

# %% [markdown]
# #### 5) Zoom in on the lower part of this graph, keep values less than 1500 only (and if their- values are higher, place it at the maximum of the plot)

# %% [markdown]
# 6) Zoom in to the upper part of this graph, keep values greater than 1500 only (and if their values are lower, remove them from the graph)

# %% [markdown]
# ### Exercise 5 : Bonus (TODO)
# ---

# %% [markdown]
# Read the file named characteristics_2016.csv containing the characteristics of each accident. Do not hesitate to go back to the documentation if necessary to better understand the columns
#
# Documentation : https://www.data.gouv.fr/fr/datasets/r/6cade01c-f69d-4779-b0a4-20606069888f
#
# File path: https://www.data.gouv.fr/fr/datasets/r/96aadc9f-0b55-4e9a-a70e-c627ed97e6f7

# %%
path = "caracteristiques_2016.csv"
caracteristiques_2016 = pd.read_csv(path, encoding="latin1")
caracteristiques_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59432 entries, 0 to 59431
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Num_Acc  59432 non-null  int64
#  1   an       59432 non-null  int64
#  2   mois     59432 non-null  int64
#  3   jour     59432 non-null  int64
#  4   hrmn     59432 non-null  int64
#  5   lum      59432 non-null  int64
#  6   agg      59432 non-null  int64
#  7   int      59432 non-null  int64
#  8   atm      59432 non-null  int64
#  9   col      59430 non-null  float64
#  10  com      59432 non-null  int64
#  11  adr      50263 non-null  object
#  12  gps      47186 non-null  object
#  13  lat      46585 non-null  float64
#  14  long     46585 non-null  float64
#  15  dep      59432 non-null  int64
# dtypes: float64(3), int64(11), object(2)
# memory usage: 7.3+ MB

# %%
caracteristiques_2016.head(10)
# Out:
#         Num_Acc  an  mois  jour  hrmn  lum  agg  int  atm  col  com  \
# 0  201600000001  16     2     1  1445    1    2    1    8  3.0    5
# 1  201600000002  16     3    16  1800    1    2    6    1  6.0    5
# 2  201600000003  16     7    13  1900    1    1    1    1  6.0   11
# 3  201600000004  16     8    15  1930    2    2    1    7  3.0  477
# 4  201600000005  16    12    23  1100    1    2    3    1  3.0   11
# 5  201600000006  16    12    23  1115    1    2    1    7  6.0   11
# 6  201600000007  16     5     1  1145    1    2    1    7  2.0   51
# 7  201600000008  16     5    14  1915    2    1    1    1  1.0  250
# 8  201600000009  16     9    23  1900    1    2    1    1  3.0   51
# 9  201600000010  16    12    30  1030    1    1    1    9  6.0  303
#
#                        adr gps  lat  long  dep
# 0       46, rue Sonneville   M  0.0   0.0  590
# 1      1a rue du cimetière   M  0.0   0.0  590
# 2                      NaN   M  0.0   0.0  590
# 3       52 rue victor hugo   M  0.0   0.0  590
# 4         rue Joliot curie   M  0.0   0.0  590
# 5  Rue Jean-baptiste LEBAS   M  0.0   0.0  590
# 6          rue Jules FERRY   M  0.0   0.0  590
# 7                      NaN   M  0.0   0.0  590
# 8                     rn41   M  0.0   0.0  590
# 9                      NaN   M  0.0   0.0  590

# %% [markdown]
# #### 1) Create a scatter plot using long and lat columns. Can you recognize the map of France? Maybe by zooming in a bit?

# %%
sns.scatterplot(data=caracteristiques_2016,x="long",y="lat")
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %% [markdown]
# #### 2) Create a time series graph, representing the evolution of traffic accidents over time. Be specific in your graph (the more details you can provide, the better it will be), while being clear to someone who is seeing it for the first time

# %%
from datetime import datetime
caracteristiques_2016['date']=caracteristiques_2016.sum(columns=['an','mois','jour'],axis=1)

#caracteristiques_2016.groupby(['an','mois','jour'])['Num_Acc'].count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\AURLIE~1\AppData\Local\Temp/ipykernel_27676/779957408.py in <module>
#       1 from datetime import datetime
# ----> 2 caracteristiques_2016['date']=caracteristiques_2016.sum(columns=['an','mois','jour'],axis=1)
#       3
#       4 #caracteristiques_2016.groupby(['an','mois','jour'])['Num_Acc'].count()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10706             **kwargs,
#   10707         ):
# > 10708             return NDFrame.sum(
#   10709                 self, axis, skipna, level, numeric_only, min_count, **kwargs
#   10710             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10444         **kwargs,
#   10445     ):
# > 10446         return self._min_count_stat_function(
#   10447             "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10448         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _min_count_stat_function(self, name, func, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10401     ):
#   10402         if name == "sum":
# > 10403             nv.validate_sum((), kwargs)
#   10404         elif name == "prod":
#   10405             nv.validate_prod((), kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\compat\numpy\function.py in __call__(self, args, kwargs, fname, max_fname_arg_count, method)
#      69                 validate_kwargs(fname, kwargs, self.defaults)
#      70             elif method == "both":
# ---> 71                 validate_args_and_kwargs(
#      72                     fname, args, kwargs, max_fname_arg_count, self.defaults
#      73                 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_validators.py in validate_args_and_kwargs(fname, args, kwargs, max_fname_arg_count, compat_args)
#     208
#     209     kwargs.update(args_dict)
# --> 210     validate_kwargs(fname, kwargs, compat_args)
#     211
#     212
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_validators.py in validate_kwargs(fname, kwargs, compat_args)
#     151     """
#     152     kwds = kwargs.copy()
# --> 153     _check_for_invalid_keys(fname, kwargs, compat_args)
#     154     _check_for_default_values(fname, kwds, compat_args)
#     155
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_validators.py in _check_for_invalid_keys(fname, kwargs, compat_args)
#     125     if diff:
#     126         bad_arg = list(diff)[0]
# --> 127         raise TypeError(f"{fname}() got an unexpected keyword argument '{bad_arg}'")
#     128
#     129
#
# TypeError: sum() got an unexpected keyword argument 'columns'

# %% [markdown]
# #### 3) Count and visualize the number of accidents by department. Show the 10 most dan- gerous departments.

# %% [markdown]
# #### 4) Create a new column having an explicit weather label. Analyze this new column for more information on accidents. When do they occur?

# %% [markdown]
# #### 5) Create two new columns, the first will contain the hour of the accident, the second will contain the minute. Which hour is the most dangerous for drivers?

# %% [markdown]
# #### 6) Analyze the most dangerous moment for each department. Does a specific moment stand out?

# %% [markdown]
# #### 7) Does Ile-de-France have more accidents than in the provinces? Create a new column and analyze the behavior in each of these two groups (Ile-de-France vs provinces). Remember to also analyze the time of day, the weather, etc.

# %% [markdown]
# #### 8) Create a new column representing 4 period of the day. Morning, afternoon, evening, night. Use this new column to analyze any correlations with other columns. Present your results in one or more graphs.
